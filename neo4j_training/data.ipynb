# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('anime.csv')

# %%
df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name   Type Episodes  \
# 0                         カウボーイビバップ     TV       26
# 1                    カウボーイビバップ 天国の扉  Movie        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17562 entries, 0 to 17561
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MAL_ID         17562 non-null  int64
#  1   Name           17562 non-null  object
#  2   Score          17562 non-null  object
#  3   Genres         17562 non-null  object
#  4   English name   17562 non-null  object
#  5   Japanese name  17562 non-null  object
#  6   Type           17562 non-null  object
#  7   Episodes       17562 non-null  object
#  8   Aired          17562 non-null  object
#  9   Premiered      17562 non-null  object
#  10  Producers      17562 non-null  object
#  11  Licensors      17562 non-null  object
#  12  Studios        17562 non-null  object
#  13  Source         17562 non-null  object
#  14  Duration       17562 non-null  object
#  15  Rating         17562 non-null  object
#  16  Ranked         17562 non-null  object
# ...

# %%
df.describe()
# Out:
#              MAL_ID    Popularity       Members      Favorites       Watching  \
# count  17562.000000  17562.000000  1.756200e+04   17562.000000   17562.000000
# mean   21477.192347   8763.452340  3.465854e+04     457.746270    2231.487758
# std    14900.093170   5059.327278  1.252821e+05    4063.473313   14046.688133
# min        1.000000      0.000000  1.000000e+00       0.000000       0.000000
# 25%     5953.500000   4383.500000  3.360000e+02       0.000000      13.000000
# 50%    22820.000000   8762.500000  2.065000e+03       3.000000      73.000000
# 75%    35624.750000  13145.000000  1.322325e+04      31.000000     522.000000
# max    48492.000000  17565.000000  2.589552e+06  183914.000000  887333.000000
#
#           Completed        On-Hold        Dropped  Plan to Watch
# count  1.756200e+04   17562.000000   17562.000000   17562.000000
# mean   2.209557e+04     955.049653    1176.599533    8199.831227
# std    9.100919e+04    4275.675096    4740.348653   23777.691963
# ...

# %%
df.isnull().sum()
# Out:
# MAL_ID           0
# Name             0
# Score            0
# Genres           0
# English name     0
# Japanese name    0
# Type             0
# Episodes         0
# Aired            0
# Premiered        0
# Producers        0
# Licensors        0
# Studios          0
# Source           0
# Duration         0
# Rating           0
# Ranked           0
# Popularity       0
# Members          0
# Favorites        0
# Watching         0
# Completed        0
# On-Hold          0
# Dropped          0
# Plan to Watch    0
# Score-10         0
# Score-9          0
# Score-8          0
# Score-7          0
# Score-6          0
# Score-5          0
# Score-4          0
# Score-3          0
# Score-2          0
# Score-1          0
# dtype: int64

# %%
df.drop(['Score-1','Score-2','Score-3','Score-4','Score-5','Score-6','Score-7','Score-8','Score-9','Score-10','Popularity',  'Members',     'Favorites',   'Watching',    'Completed',   'On-Hold',     'Dropped',     'Plan to Watch','Premiered', 'Aired', 'Japanese name', 'English name'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17562 entries, 0 to 17561
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MAL_ID     17562 non-null  int64
#  1   Name       17562 non-null  object
#  2   Score      17562 non-null  object
#  3   Genres     17562 non-null  object
#  4   Type       17562 non-null  object
#  5   Episodes   17562 non-null  object
#  6   Producers  17562 non-null  object
#  7   Licensors  17562 non-null  object
#  8   Studios    17562 non-null  object
#  9   Source     17562 non-null  object
#  10  Duration   17562 non-null  object
#  11  Rating     17562 non-null  object
#  12  Ranked     17562 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 1.7+ MB

# %%
def delete_unknown_rows(dataframe):
    # Filter out rows that contain 'Unknown' in any column
    df_cleaned = df[~df.isin(['Unknown']).any(axis=1)]
    return df_cleaned

# %%
df = delete_unknown_rows(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2762 entries, 0 to 17224
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MAL_ID     2762 non-null   int64
#  1   Name       2762 non-null   object
#  2   Score      2762 non-null   object
#  3   Genres     2762 non-null   object
#  4   Type       2762 non-null   object
#  5   Episodes   2762 non-null   object
#  6   Producers  2762 non-null   object
#  7   Licensors  2762 non-null   object
#  8   Studios    2762 non-null   object
#  9   Source     2762 non-null   object
#  10  Duration   2762 non-null   object
#  11  Rating     2762 non-null   object
#  12  Ranked     2762 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 302.1+ KB

# %%
df.to_csv('data.csv', index=False)
